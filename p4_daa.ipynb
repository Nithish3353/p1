# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithish3353/p1/blob/main/p4_daa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time


# Iterative factorial
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# Recursive factorial
def factorial_recursive(n):
    if n <= 1:
        return 1

    return n * factorial_recursive(n - 1)


# Take input from the user
n = int(input("Enter a non-negative integer: "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")

else:
    # Measure iterative factorial time
    start = time.perf_counter_ns()
    result_iterative = factorial_iterative(n)
    end = time.perf_counter_ns()

    iterative_time = end - start


    # Measure recursive factorial time
    start = time.perf_counter_ns()
    result_recursive = factorial_recursive(n)
    end = time.perf_counter_ns()

    recursive_time = end - start


    # Display the results
    print("\n--- Results for", n, "! ---")

    print("Iterative Result :", result_iterative)
    print("Iterative Time   :", iterative_time, "ns")

    print("-----------------------------")

    print("Recursive Result :", result_recursive)
    print("Recursive Time   :", recursive_time, "ns")
# Out:
# Enter a non-negative integer: 17
#
# --- Results for 17 ! ---
# Iterative Result : 355687428096000
# Iterative Time   : 5033 ns
# -----------------------------
# Recursive Result : 355687428096000
# Recursive Time   : 3559 ns
