# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithish3353/DAA-/blob/main/Daa_p5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def knapsack(W, wt, val, n):

    # Create DP table
    dp = [[0 for _ in range(W + 1)] for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for w in range(1, W + 1):

            # If item can fit in the bag
            if wt[i - 1] <= w:

                # Choose maximum:
                # 1. Include the item
                # 2. Exclude the item
                dp[i][w] = max(
                    val[i - 1] + dp[i - 1][w - wt[i - 1]],
                    dp[i - 1][w]
                )

            else:
                # Item cannot fit
                dp[i][w] = dp[i - 1][w]

    return dp[n][W]


# Main program

n = int(input("Enter number of items: "))

wt = list(map(int, input("Enter weights: ").split()))

val = list(map(int, input("Enter values: ").split()))

W = int(input("Enter capacity of knapsack: "))

max_value = knapsack(W, wt, val, n)

print("Maximum value =", max_value)
# Out:
# Enter number of items: 4
# Enter weights: 1 3 4 5
# Enter values: 1 4 5 7
# Enter capacity of knapsack: 7
# Maximum value = 9
